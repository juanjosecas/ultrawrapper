# %% [markdown]
# # 07 – Model Export & Benchmarking
#
# Export to ONNX / OpenVINO / TFLite and benchmark latency.

# %%
from vision.yolo.export import export_model, benchmark_export
from vision.yolo.benchmarks import benchmark_inference

# %%
# Export to ONNX
# result = export_model('yolo11n.pt', fmt='onnx', imgsz=640)
# print('Exported to:', result['exported_path'])

# %%
# Benchmark the exported model
# bench = benchmark_export('yolo11n.pt', fmt='onnx', n_runs=50)
# print(bench)

# %%
# Benchmark raw PyTorch inference
# df = benchmark_inference('yolo11n.pt', imgsz=640, n_runs=100)
# print(df[['latency_mean_ms', 'fps', 'ram_used_mb']])
