# %% [markdown]
# # 05 – Training
#
# Train, resume, and validate a YOLO model.
# Metrics are saved as parquet alongside Ultralytics outputs.

# %%
from vision.yolo.train import train_model, resume_training, validate_model
from vision.yolo.plotting import plot_training_metrics

# %%
# result = train_model(
#     'yolo11n.pt',
#     data='path/to/data.yaml',
#     epochs=50,
#     imgsz=640,
#     batch=16,
#     save_metrics=True,
#     metrics_fmt='parquet',
# )
# print('Best weights:', result['best_weights'])
# print(result['metrics'].head())

# %%
# Plot training curves
# fig = plot_training_metrics(result['metrics'])
# fig.show()

# %%
# Validate
# val_df = validate_model(result['best_weights'], data='path/to/data.yaml')
# print(val_df)
