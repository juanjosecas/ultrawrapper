# %% [markdown]
# # 07 - Exportación y benchmark
#
# Ejemplos directos de exportación y medición de rendimiento.

# %%
import os

from vision.yolo.export import export_model, benchmark_export
from vision.yolo.benchmarks import benchmark_inference

NOTEBOOK_DIR = os.path.abspath("notebooks")
OUTPUT_DIR = os.path.join(NOTEBOOK_DIR, "outputs")
os.makedirs(OUTPUT_DIR, exist_ok=True)

MODEL = "yolo11n.pt"

# %% [markdown]
# ## Exportar a ONNX

# %%
# exported = export_model(
#     MODEL,
#     fmt="onnx",
#     imgsz=640,
# )
# exported

# %% [markdown]
# ## Benchmark del modelo PyTorch

# %%
# benchmark = benchmark_inference(
#     MODEL,
#     imgsz=640,
#     n_runs=30,
#     save_to=os.path.join(OUTPUT_DIR, "07_benchmark.parquet"),
# )
# benchmark

# %% [markdown]
# ## Benchmark del modelo exportado

# %%
# export_benchmark = benchmark_export(
#     MODEL,
#     fmt="onnx",
#     n_runs=30,
# )
# export_benchmark
