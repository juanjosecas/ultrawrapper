# %% [markdown]
# # 08 - Conversión de anotaciones
#
# Conversión entre COCO, YOLO, VOC y LabelMe mediante una única función de alto nivel.

# %%
import os

from vision.yolo.annotations.convert import convert_annotations

NOTEBOOK_DIR = os.path.abspath("notebooks")
OUTPUT_DIR = os.path.join(NOTEBOOK_DIR, "outputs")
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# ## COCO → YOLO
#
# Las rutas se pasan como strings. La conversión interna resuelve los detalles de cada formato.

# %%
SOURCE_DIR = "path/to/coco_dataset"
TARGET_DIR = os.path.join(OUTPUT_DIR, "08_yolo_dataset")
CLASS_NAMES = ["cat", "cell"]

# samples = convert_annotations(
#     source_dir=SOURCE_DIR,
#     target_dir=TARGET_DIR,
#     source_fmt="coco",
#     target_fmt="yolo",
#     class_names=CLASS_NAMES,
# )
# print("Muestras convertidas:", len(samples))

# %% [markdown]
# ## YOLO → LabelMe

# %%
YOLO_DIR = "path/to/yolo_labels"
LABELME_DIR = os.path.join(OUTPUT_DIR, "08_labelme_dataset")

# samples = convert_annotations(
#     source_dir=YOLO_DIR,
#     target_dir=LABELME_DIR,
#     source_fmt="yolo",
#     target_fmt="labelme",
#     class_names=CLASS_NAMES,
# )

# %% [markdown]
# ## Qué conviene revisar después de convertir
#
# Comparar número de imágenes, número de anotaciones por clase y algunas imágenes al azar antes de usar el dataset para entrenamiento.
